# %%
import pandas as pd
import quandl

# %%
quandl.ApiConfig.api_key = '1qqA2P4yyiY5bPaauktM'
df =quandl.get('LPPM/PALL', start_date='2011-03-08', end_date='2021-03-08')

# %%
df.plot(figsize=(15,15))
# Out:
# <AxesSubplot:xlabel='Date'>
